# %%
cd ../tele
# Out:
# /home/sean/Code/gym-uav/tele

# %%
import findjam
import torch

# %%
J = findjam.JamsGrid(ngrid=10, ncomms=2, njams=2, move=False, seed=0)

# %%
J.run(10)

# %%
J.render()

# %% [markdown]
# In above, estimates are spot on after only 10 steps.  Remember, jammer positions are real numbers, estimates of those positions are integers appoximating the real numbers.  This is as good as it can get.

# %%
J.jammers
# Out:
# [(3.8128931940501425, 5.813047017599905),
#  (3.9382849013642325, 8.025957007038718)]

# %%
J.estimates()
# Out:
# (tensor(4), tensor(8), tensor(4), tensor(6))

# %%
JM = findjam.JamsGrid(ngrid=10, ncomms=2, njams=2, move=True, seed=0)

# %%
JM.run(10)

# %%
JM.render()

# %%
JM.render_prior()

# %%
JM.render_prediction()

# %%
JM.render_update()

# %%
JM.render()

# %%
JK = findjam.JamsGrid(ngrid=10, ncomms=1, njams=1, move=True, seed=0)

# %%
JK.run(10)

# %%
JK.render()0

# %%
JK.render_prior()

# %%
JK.render_prediction()

# %%
JK.render_update()

# %%
JK.render()

# %%
JK = findjam.JamsGrid(ngrid=10, ncomms=1, njams=1, move=True, seed=0)

# %%
JK.run(1)

# %%
JK.render()

# %%
print(JK.jammers)
JK.estimates()
# Out:
# [(5.4248703846447945, 4.903948646972072)]
# (tensor(6), tensor(7))

# %%
JK.run(1)

# %%
JK.render_prediction()

# %%
JK.render_update()

# %%
JK.render()

# %%
JK.run()

# %%
JK.render()

# %%
print(JK.jammers)
JK.estimates()
# Out:
# [(5.4248703846447945, 5.903948646972072)]
# (tensor(6), tensor(7))

# %%
JK.run()
JK.render()

# %%
print(JK.jammers)
JK.estimates()
# Out:
# [(5.4248703846447945, 5.903948646972072)]
# (tensor(6), tensor(5))

# %%
JK.render_update()

# %%
print(JK.jammers)
JK.estimates()
# Out:
# [(5.4248703846447945, 5.903948646972072)]
# (tensor(6), tensor(5))

# %%
JK = findjam.JamsGrid(ngrid=10, ncomms=1, njams=1, move=True, seed=0)

# %%
JK.run(1)
print(JK.jammers)
JK.estimates()
# Out:
# [(6.4248703846447945, 5.903948646972072)]
# (tensor(9), tensor(3))
